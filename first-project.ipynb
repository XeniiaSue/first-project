# %% [markdown]
# <span style="color: blue; font-size: 20px; font-weight: bold;">Комментарий ревьюера</span>
#
# <span style="color: blue">Привет, Ксения! Меня зовут Павел Григорьев, и я буду проверять этот проект.<br>Моя основная цель - не указать на совершённые тобой ошибки, а поделиться своим опытом и помочь тебе совершенствоваться как профессионалу.<br>Спасибо за проделанную работу! Предлагаю общаться на «ты».</span>
# <details>
# 	<summary><u>Инструкция по организационным моментам (кликабельно)</u>⤵</summary>
# <span style="color: blue">Я буду использовать различные цвета, чтобы было удобнее воспринимать мои комментарии:</span>
#
#
# ---
#
#
# <span style="color: blue">синий текст - просто текст комментария</span>
#
# <span style="color: green">✔️ и зеленый текст - все отлично</span>
#
# <span style="color: orange">⚠️ и оранжевый текст - сделано все правильно, однако есть рекомендации, на что стоит обратить внимание</span>
#
# <span style="color: red">❌ и красный текст - есть недочеты</span>
#
#
# </details>
# </br>
# <span style="color: blue">Пожалуйста, не удаляй мои комментарии в случае возврата работы, так будет проще разобраться, какие были недочеты, а также сразу увидеть исправленное.</span>
#
# <span style="color: blue">Ответы на мои комментарии лучше тоже помечать.<br>
# Например: </span><br><span style="color: purple; font-weight: bold">Комментарий студента</span>
#
# <span style="color: blue; font-weight: bold;">Давай смотреть, что получилось!</span>

# %% [markdown]
# <span style="color: blue; font-size: 18px; font-weight: bold;">Комментарий ревьюера 2</span>
#
# <span style="color: blue">Привет еще раз. Спасибо, за исправления. Оформление комментариев по работе сохраняется. Только обозначим, что это вторая итерация.</span>

# %% [markdown]
# <span style="color: blue; font-size: 18px; font-weight: bold;">Комментарий ревьюера 3</span>
#
# <span style="color: blue">Привет еще раз. Спасибо, за исправления. Оформление комментариев по работе сохраняется.</span>

# %% [markdown]
# <span style="color: blue; font-size: 18px; font-weight: bold;">Комментарий ревьюера 4</span>
#
# <span style="color: blue">Привет еще раз. Спасибо, за исправления. Оформление комментариев по работе сохраняется.</span>

# %% [markdown]
# # ОПИСАНИЕ ПРОЕКТА

# %% [markdown]
# HR-аналитики компании «Работа с заботой» помогают бизнесу оптимизировать управление персоналом: бизнес предоставляет данные, а аналитики предлагают, как избежать финансовых потерь и оттока сотрудников. В этом HR-аналитикам помогает машинное обучение, с помощью которого получается быстрее и точнее отвечать на вопросы бизнеса: удовлетворённость работой напрямую влияет на отток сотрудников. А предсказание оттока — одна из важнейших задач HR-аналитиков. Внезапные увольнения несут в себе риски для компании, особенно если уходит важный сотрудник.
#
#
# Компания предоставила данные с характеристиками сотрудников компании. Среди них — уровень удовлетворённости сотрудника работой в компании. Эту информацию получили из форм обратной связи: сотрудники заполняют тест-опросник, и по его результатам рассчитывается доля их удовлетворённости от 0 до 1, где 0 — совершенно неудовлетворён, 1 — полностью удовлетворён.
# Собирать данные такими опросниками не так легко: компания большая, и всех сотрудников надо сначала оповестить об опросе, а затем проследить, что все его прошли.

# %% [markdown]
# **Цель исследования**
#
# Пстроить модель, которая сможет предсказать уровень удовлетворённости сотрудника на основе данных заказчика, а затем — модель, которая сможет предсказать увольнение сотрудника из компании.

# %% [markdown]
# **Что нам известно**
#
# В нашем распоряжении датасеты с тренировочными и тестовыми выборками и вот какие данные в них содержатся:
#
# -	id — уникальный идентификатор сотрудника;
# -	dept — отдел, в котором работает сотрудник;
# -	level — уровень занимаемой должности;
# -	workload — уровень загруженности сотрудника;
# -	employment_years — длительность работы в компании (в годах);
# -	last_year_promo — показывает, было ли повышение за последний год;
# -	last_year_violations — показывает, нарушал ли сотрудник трудовой договор за последний год;
# -	supervisor_evaluation — оценка качества работы сотрудника, которую дал руководитель;
# -	salary — ежемесячная зарплата сотрудника;
# -	job_satisfaction_rate — уровень удовлетворённости сотрудника работой в компании, целевой признак для первой задачи;
# -   quit — показывает, уволился ли сотрудник из компании, это целевой признак лдя второй задачи.

# %% [markdown]
# **Ход исследования**
#
# В рамках первой задачи (предсказание удовлетворенности сотрудника):
#  - Подготовим данные: загрузим и изучим общую информацию из предоставленных датасетов;
#  - предобработаем данные: обработаем пропущенные значения в пайплайне, найдем дубликаты, скорректируем типы данных;
#  - проведем исследовательский анализ данных;
#  - попробуем составить «портрет довольного сотрудника»
#  - проведем корреляционный анализ данных;
#  - построим пайплайны — при кодировании используем два кодировщика;
#  - обучим две модели;
#  - лучшую модель проверим с помощью метрики SMAPE;
#  - проведем анализ важности признаков;
#  - проведем сегментацию покупателей;
#  - сформулируем выводы.
#
#  В рамках второй задачи (предсказание увольнения сотрудника):
#  - Подготовим данные: загрузим и изучим общую информацию из предоставленных датасетов;
#  - предобработаем данные: обработаем пропущенные значения в пайплайне, найдем дубликаты, скорректируем типы данных;
#  - проведем исследовательский анализ данных: составим «портрет уволившегося сотрудника»;
#  - посмотрим, есть ли взаимосвязь между целевыми признаками (уволнение и удовлетворенность работой);
#  - добавим к исследованию новый входной признак — степень удовлетворенности работой, которую рассчитала лучшая модель в рамках первой задачи;
#  - построим пайплайны — при кодировании используем два кодировщика;
#  - обучим три модели;
#  - лучшую модель проверим с помощью метрики ROC-AUC;
#  - проведем анализ важности признаков;
#  - проведем сегментацию покупателей;
#  - сформулируем промежуточные выводы;
#  - сформулируем общие выводы.

# %% [markdown]
# Приступим к работе.

# %% [markdown]
# ## Задача 1: Предсказание уровня удовлетворённости сотрудника

# %% [markdown]
# Для этой задачи заказчик предоставил:
#
# - тренировочную выборку train_job_satisfaction_rate.csv
# - входные признаки тестовой выборки test_features.csv
# - целевой признак тестовой выборки test_target_job_satisfaction_rate.csv.

# %% [markdown]
# Загрузим данные библиотек и инструментов, а затем — датасеты.

# %% [markdown]
# ###  Загрузка библиотек и инструментов

# %%
# !pip install -q --upgrade scikit-learn
# !pip install -q matplotlib==3.7.3
# !pip install -q --upgrade numba
# !pip install -q --upgrade shap
# !pip -q install phik

# %%
import shap 
import pandas as pd
import numpy as np 
import phik
from matplotlib import pyplot as plt
import seaborn as sns 
from scipy import stats as st 
import sklearn

#Импорт необходимых библиотек, классов и методов
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.preprocessing import StandardScaler, OneHotEncoder, OrdinalEncoder, MinMaxScaler, LabelEncoder
from sklearn.metrics import roc_auc_score, make_scorer
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.compose import ColumnTransformer
from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier, plot_tree
from sklearn.impute import SimpleImputer 
from sklearn.feature_selection import SelectKBest, f_classif, mutual_info_regression
import warnings
warnings.filterwarnings("ignore")

RANDOM_STATE = 42
TEST_SIZE = 0.25

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ✔️\
# <font color='green'> Хорошее оформление импортов! \
# Но их лучше собрать в одной ячейке и разделить на функциональные группы пустой строкой.</font>

# %% [markdown]
# <div class="alert alert-info">
#
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
#
#
# Сделано.
#
# </div>

# %% [markdown]
# <span style="color: blue; font-weight: bold">Комментарий ревьюера 2: </span> ✔️\
# <span style="color: green"> 👍</span>

# %% [markdown]
# ### Шаг 1. Загрузка данных из таблиц

# %%
df = pd.read_csv('https://code.s3.yandex.net/datasets/train_job_satisfaction_rate.csv')
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     4000 non-null   int64
#  1   dept                   3994 non-null   object
#  2   level                  3996 non-null   object
#  3   workload               4000 non-null   object
#  4   employment_years       4000 non-null   int64
#  5   last_year_promo        4000 non-null   object
#  6   last_year_violations   4000 non-null   object
#  7   supervisor_evaluation  4000 non-null   int64
#  8   salary                 4000 non-null   int64
#  9   job_satisfaction_rate  4000 non-null   float64
# dtypes: float64(1), int64(4), object(5)
# memory usage: 312.6+ KB
#        id        dept   level workload  employment_years last_year_promo  \
# 0  155278       sales  junior   medium                 2              no
# ...

# %%
test_features = pd.read_csv('/datasets/test_features.csv')
test_features.info()
test_features.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     2000 non-null   int64
#  1   dept                   1998 non-null   object
#  2   level                  1999 non-null   object
#  3   workload               2000 non-null   object
#  4   employment_years       2000 non-null   int64
#  5   last_year_promo        2000 non-null   object
#  6   last_year_violations   2000 non-null   object
#  7   supervisor_evaluation  2000 non-null   int64
#  8   salary                 2000 non-null   int64
# dtypes: int64(4), object(5)
# memory usage: 140.8+ KB
#        id        dept   level workload  employment_years last_year_promo  \
# 0  485046   marketing  junior   medium                 2              no
# 1  686555          hr  junior   medium                 1              no
# ...

# %%
test_target_job_satisfaction_rate = pd.read_csv('/datasets/test_target_job_satisfaction_rate.csv')
test_target_job_satisfaction_rate.info()
test_target_job_satisfaction_rate.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     2000 non-null   int64
#  1   job_satisfaction_rate  2000 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 31.4 KB
#        id  job_satisfaction_rate
# 0  130604                   0.74
# 1  825977                   0.75
# 2  418490                   0.60
# 3  555320                   0.72
# 4  826430                   0.08
# 5  817219                   0.76
# 6  269033                   0.64
# 7  962356                   0.38
# 8  649052                   0.14
# 9  532834                   0.59

# %% [markdown]
# Мы загрузили и прочли данные из таблиц, посмотрели основную информацию.

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ✔️\
# <font color='green'>Данные загружены корректно, первичный осмотр проведен.</font>

# %% [markdown]
# ### Шаг 2. Предобработка данных

# %% [markdown]
# На этом шаге проведем предобработку: изучим данные, если найдем пропуски — заполним их в пайплайне.

# %% [markdown]
# #### Явные дубликаты

# %% [markdown]
# Проверим явные дубликаты.

# %%
df.duplicated().sum()
# Out:
# 0

# %%
test_features.duplicated().sum()
# Out:
# 0

# %%
test_target_job_satisfaction_rate.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Неявные дубликаты

# %% [markdown]
# Явных дубликатов нет, поищем неявные.

# %%
# сначала в таблице df
df['dept'].unique()
# Out:
# array(['sales', 'hr', 'technology', 'purchasing', 'marketing', nan],
#       dtype=object)

# %%
df['level'].unique()
# Out:
# array(['junior', 'middle', 'sinior', nan], dtype=object)

# %%
# исправим опечатку
df['level'] = df['level'].replace('sinior','senior')

# %%
df['level'].unique()
# Out:
# array(['junior', 'middle', 'senior', nan], dtype=object)

# %%
df['workload'].unique()
# Out:
# array(['medium', 'high', 'low'], dtype=object)

# %%
df['employment_years'].unique()
# Out:
# array([ 2,  1,  4,  7,  9,  6,  3, 10,  8,  5])

# %%
df['last_year_promo'].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
df['last_year_violations'].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
df['supervisor_evaluation'].unique()
# Out:
# array([1, 5, 2, 3, 4])

# %%
# теперь в таблице test_features
test_features['dept'].unique()
# Out:
# array(['marketing', 'hr', 'sales', 'purchasing', 'technology', nan, ' '],
#       dtype=object)

# %%
test_features['level'].unique()
# Out:
# array(['junior', 'middle', 'sinior', nan], dtype=object)

# %%
# исправим опечатку
test_features['level'] = test_features['level'].replace('sinior','senior')

# %%
test_features['level'].unique()
# Out:
# array(['junior', 'middle', 'senior', nan], dtype=object)

# %%
test_features['workload'].unique()
# Out:
# array(['medium', 'low', 'high', ' '], dtype=object)

# %%
test_features['employment_years'].unique()
# Out:
# array([ 2,  1,  5,  6,  3,  9,  7,  4,  8, 10])

# %%
test_features['last_year_promo'].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
test_features['last_year_violations'].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
test_features['supervisor_evaluation'].unique()
# Out:
# array([5, 4, 3, 1, 2])

# %% [markdown]
# В столбцах `'dept'` и `'workload'` тестовой выборки нашлись пустые значения, заполним их позже в пайплайне самыми часто встречающимися значениями.

# %% [markdown]
# <span style="color: blue; font-weight: bold">Комментарий ревьюера : </span> ⚠️\
# <span style="color: darkorange"> Нужо отметить "лишние" категории в тестовых данных.</span>

# %% [markdown]
# <div class="alert alert-info">
#
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# Уточни, пожалуйста, что это значит? Как я могу на этапе предобработки понять, что они дальше не пригодятся и как именно их нужно отметить? Мы же о признаках сейчас говорим?
#
# </div>

# %% [markdown]
# <span style="color: blue; font-weight: bold">Комментарий ревьюера 2: </span> ⚠️\
# <span style="color: darkorange"> Сравни количество уникальных значений в признаке 'workload', например, в обучающей и тестовой выборках. ))</span>

# %% [markdown]
# <div class="alert alert-info">
#
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# Готово — заменила их на `nan`.
#
# </div>

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера 3: </b></font> ❌\
# <font color='red'>  ~~Здорово, что отмечено новое значение в категориях, но такие значения нужно обработать в Пайплайн, инструментами Энкодеров.~~</font>

# %% [markdown]
# <div class="alert alert-info">
#
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
#
#
# Спасибо, поправила, оставила комментарий.
#
# </div>

# %% [markdown]
# <span style="color: blue; font-weight: bold">Комментарий ревьюера 4: </span> ✔️\
# <span style="color: green"> Отлично!  👍</span>

# %% [markdown]
# #### Пропуски

# %% [markdown]
# Поищем пропуски в таблицах.

# %%
df.isna().sum()
# Out:
# id                       0
# dept                     6
# level                    4
# workload                 0
# employment_years         0
# last_year_promo          0
# last_year_violations     0
# supervisor_evaluation    0
# salary                   0
# job_satisfaction_rate    0
# dtype: int64

# %% [markdown]
# Пропуски есть, заполним их в пайплайне при обучении моделей.

# %%
# создадим объект класса SimpleImputer с параметром strategy = 'most_frequent'
imp_most_freq = SimpleImputer(strategy = 'most_frequent')
# в дальнейшем применим метод .fit_transform() к столбцу dept

# %%
# применим метод .fit_transform() к столбцу level
df['level'] = imp_most_freq.fit_transform(df[['level']]).ravel()

# %% [markdown]
# Таким же образом поступим с остальными пропусками

# %%
test_features.isna().sum()
# Out:
# id                       0
# dept                     2
# level                    1
# workload                 0
# employment_years         0
# last_year_promo          0
# last_year_violations     0
# supervisor_evaluation    0
# salary                   0
# dtype: int64

# %%
# применим метод .fit_transform() к столбцу dept
test_features['dept'] = imp_most_freq.fit_transform(test_features[['dept']]).ravel()

# %%
# применим метод .fit_transform() к столбцу dept
test_features['level'] = imp_most_freq.fit_transform(test_features[['level']]).ravel()

# %% [markdown]
# <span style="color: blue; font-weight: bold">Комментарий ревьюера : </span>  ❌\
# <span style="color: red">~~Для корректной кросс-валидации, заполнение пропусков нужно объединить с обучением моделей через Pipeline, для избегания утечек между обучающими и валидационными подвыборками.~~</span>\
# <span style="color: blue">На данном этапе достаточно обнаружить пропуски и объявить какими инструментами и стратегиями они будут обрабатыватьсся в Пайплайне.</span>

# %% [markdown]
# <div class="alert alert-info">
#
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# Тогда не очень понятно, почему в инструкции сказано вот так:
#
# Шаг 2. Предобработка данных
# Изучите данные и сделайте выводы. При необходимости выполните предобработку. Если есть пропуски, заполните их в пайплайне.
# ...
#
# Шаг 4. Подготовка данных
# Подготовку признаков выполните в пайплайне, дополнив пайплайн шага предобработки.
#
# Разве это не означает, что нужно заполнять пропуски в пайплайне уже на втором шаге? Если нет — то стоит изменить формулировку задания.
#
# </div>

# %% [markdown]
# <span style="color: blue; font-weight: bold">Комментарий ревьюера 2: </span> \
# <span style="color: red">~~Пайплайн для заполнения можно начать собирать тут (показать какими инструментами и стратегиями пропуски будут обрабатываться). НО данные обрабатывать только при обучении моделей, после окончательного формирования (дополнив пайплайн шага предобработки). Это необходимо для для корректной кросс-валидации.~~</span>

# %% [markdown]
# <div class="alert alert-info">
#
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
#
#
# Переделала, не стала заполнять пропуски на этом этапе.
#
# </div>

# %% [markdown]
# <span style="color: blue; font-weight: bold">Комментарий ревьюера 3: </span> ✔️\
# <span style="color: green"> Отлично!  👍</span>

# %%
test_target_job_satisfaction_rate.isna().sum()
# Out:
# id                       0
# job_satisfaction_rate    0
# dtype: int64

# %% [markdown]
# А в третьей таблице пропусков нет — все хорошо.

# %% [markdown]
# #### Сортировка столбцов по id

# %%
test_features = test_features.sort_values(by='id').reset_index(drop=True)
test_features.head()
# Out:
#        id        dept   level workload  employment_years last_year_promo  \
# 0  100298          hr  junior      low                 2              no
# 1  100480   marketing  junior      low                 4              no
# 2  100503  purchasing  middle     high                 5              no
# 3  100610       sales  middle   medium                 5              no
# 4  100692       sales  middle     high                 6              no
#
#   last_year_violations  supervisor_evaluation  salary
# 0                   no                      4   19200
# 1                   no                      4   16800
# 2                   no                      4   55200
# 3                   no                      4   43200
# 4                   no                      4   48000

# %%
test_target_job_satisfaction_rate = test_target_job_satisfaction_rate.sort_values(by='id').reset_index(drop=True)
test_target_job_satisfaction_rate.head()
# Out:
#        id  job_satisfaction_rate
# 0  100298                   0.80
# 1  100480                   0.84
# 2  100503                   0.79
# 3  100610                   0.75
# 4  100692                   0.69

# %% [markdown]
# <span style="color: blue; font-weight: bold">Комментарий ревьюера : </span> ✔️\
# <span style="color: green"> 👍</span>

# %% [markdown]
# На этом шаге мы провели предобработку данных: убедились, что типы данных в столбцах соответствуют содержимому, нашли пропуски и заполнили их в пайплайне, проверили наличие дубликатов, отсортировали таблицы. Данные в таблицах прилично выглядят, столбцы названы нормально, в змеином регистре, все выглядит консистентно.

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ✔️ <br>
# <font color='green'>Здорово, что не забываешь про промежуточные выводы.</font>

# %% [markdown]
# ### Шаг 3. Исследовательский анализ данных

# %% [markdown]
# На этом шаге исследуем все признаки, визуализируем их распределение — построим графики — и попробуем увидеть зависимости.

# %% [markdown]
# #### Графики для таблицы df

# %%
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     4000 non-null   int64
#  1   dept                   3994 non-null   object
#  2   level                  4000 non-null   object
#  3   workload               4000 non-null   object
#  4   employment_years       4000 non-null   int64
#  5   last_year_promo        4000 non-null   object
#  6   last_year_violations   4000 non-null   object
#  7   supervisor_evaluation  4000 non-null   int64
#  8   salary                 4000 non-null   int64
#  9   job_satisfaction_rate  4000 non-null   float64
# dtypes: float64(1), int64(4), object(5)
# memory usage: 312.6+ KB
#        id        dept   level workload  employment_years last_year_promo  \
# 0  155278       sales  junior   medium                 2              no
# ...

# %% [markdown]
# Сначала оценим дискретные признаки.

# %%
# построим графики
fig, axes = plt.subplots(figsize=(10,6))
plt.title('Распределение признака «Длительность работы в компании»', fontsize=16)
sns.countplot(x = 'employment_years', data = df, palette='pastel')
plt.xlabel('Количество проработанных лет', fontsize=13)
plt.ylabel('Количество сотрудников', fontsize=13)
plt.show()

# %% [markdown]
# Довольно много сотрудников работает в компании меньше четырех лет. В отрыве от других показателей ничего тревожного в этом нет, но все-таки, на первый взгляд, многовато людей, которые работают первый-второй год.

# %%
fig, axes = plt.subplots(figsize=(10,6))
plt.title('Распределение признака «Оценка качества работы»', fontsize=16)
sns.countplot(x = 'supervisor_evaluation', data = df, palette='pastel')
plt.xlabel('Оценка, которую выставил руководитель', fontsize=13)
plt.ylabel('Количество сотрудников', fontsize=13)
plt.show()

# %% [markdown]
# Как мы видим, 3 и 4 — самые распространенные оценки, выставленные руковдоителем. Мы не знаем, что должны сделать сотрудники, чтобы стать отличниками: означает ли 5 просто отличную работу (то есть, нечто условное, с примесью субъетивизма) или достижение каких-то особенных показателей.

# %% [markdown]
# Теперь оценим категориальные признаки.

# %%
# напишем функцию для построения диаграмм
def pie_graph(dataset, column, name, n, i):
    plt.subplot(1, n, i)
    plt.title(column)
    plt.pie(x=dataset.groupby(column)[name].count(),
            startangle=90,
            labeldistance=1.1, 
            wedgeprops={'linewidth':3, 'edgecolor':'white'}, 
            autopct='%1.1f%%',
            labels=dataset.groupby(column)[name].count().index, 
            colors=sns.color_palette('BuPu_r'))

# %%
# перечислим нужные признаки  
cat_col_df = ['dept', 'level', 'workload', 'last_year_promo', 'last_year_violations']

# %%
# построим круговые диаграммы
i = 1
plt.figure(figsize=(18,15))
for name in cat_col_df:
    pie_graph(df, name, 'id', len(cat_col_df), i)
    i += 1

# %% [markdown]
# Среди тех, кто заполнил анкету, лидируют представители отдела продаж, на втором месте — сотрудники технического/технологического подразделения, на третьем — отдела закупок.
#
# Примерно поровну отметилось джуниоров и мидлов, только десятая часть считается сениорами.
#
# Половина сотрудников загружены средне, треть — недогружены, чуть меньше чем 20% грозит выгорание.
#
# Практически никого не повысили в прошедшем году, седьмая часть сотрудников нарушала договор.

# %% [markdown]
# Рассмотрим количественные признаки.

# %%
fig, axes = plt.subplots(figsize=(10,6))
df['salary'].hist(bins=50)
plt.title('Распределение зарплат в компании', fontsize=16)
plt.xlabel('Размер зарплаты', fontsize=13)
plt.ylabel('Количество сотрудников', fontsize=13)
plt.show()

# %% [markdown]
# Самый распространенный размер зарплат в компании — это от 20 до 30 тысяч.

# %%
fig, axes = plt.subplots(figsize=(10,6))
df['job_satisfaction_rate'].hist(bins=50)
plt.title('Уровень удовлетворенности сотрудников', fontsize=16)
plt.xlabel('Оценка удовлетворенности от 0 до 1', fontsize=13)
plt.ylabel('Количество сотрудников', fontsize=13)
plt.show()

# %% [markdown]
# Признак распределен нормально, относительно равномерно.

# %% [markdown]
# #### Графики для таблицы test_features

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера : </b></font> ✔️\
# <font color='green'> Здорово, что сравниваешь выборки!</font>

# %%
test_features.info()
test_features.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     2000 non-null   int64
#  1   dept                   2000 non-null   object
#  2   level                  2000 non-null   object
#  3   workload               2000 non-null   object
#  4   employment_years       2000 non-null   int64
#  5   last_year_promo        2000 non-null   object
#  6   last_year_violations   2000 non-null   object
#  7   supervisor_evaluation  2000 non-null   int64
#  8   salary                 2000 non-null   int64
# dtypes: int64(4), object(5)
# memory usage: 140.8+ KB
#        id        dept   level workload  employment_years last_year_promo  \
# 0  100298          hr  junior      low                 2              no
# 1  100480   marketing  junior      low                 4              no
# ...

# %%
fig, axes = plt.subplots(figsize=(10,6))
plt.title('Распределение признака «Длительность работы в компании»', fontsize=16)
sns.countplot(x = 'employment_years', data = test_features, palette='pastel')
plt.xlabel('Количество проработанных лет', fontsize=13)
plt.ylabel('Количество сотрудников', fontsize=13)
plt.show()

# %% [markdown]
# Здесь также лидируют новички, но есть и пиковое значение на отметке 7 — это хорошая тенденция: люди задерживаются.

# %%
fig, axes = plt.subplots(figsize=(10,6))
plt.title('Распределение признака «Оценка качества работы»', fontsize=16)
sns.countplot(x = 'supervisor_evaluation', data = test_features, palette='pastel')
plt.xlabel('Оценка, которую выставил руководитель', fontsize=13)
plt.ylabel('Количество сотрудников', fontsize=13)
plt.show()

# %% [markdown]
# Руководитель также щедро ставит тройки и четверки.

# %%
# построим круговые диаграммы
i = 1
plt.figure(figsize=(18,15))
for name in cat_col_df:
    pie_graph(test_features, name, 'id', len(cat_col_df), i)
    i += 1

# %% [markdown]
# Если смотреть на принадлежность к разным департаментам — лидируют продажники, технари и маркетинг.
# Меньше 10% опрошенных сотрудников высокоранговые, половина загружена средне, треть — недогружена. Очень маленький процент получил повышения в прошедшем году, седьмая часть нарушили договор.

# %%
fig, axes = plt.subplots(figsize=(10,6))
test_features['salary'].hist(bins=50)
plt.title('Распределение зарплат в компании', fontsize=16)
plt.xlabel('Размер зарплаты', fontsize=13)
plt.ylabel('Количество сотрудников', fontsize=13)
plt.show()

# %% [markdown]
# Рапределение зарплат смещено влево, но в целом не отличается от типовой картины в крупной компании: большинство получают мало, меньшинство — много.

# %% [markdown]
# #### График для таблицы test_target_job_satisfaction_rate

# %%
test_target_job_satisfaction_rate.info()
test_target_job_satisfaction_rate.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     2000 non-null   int64
#  1   job_satisfaction_rate  2000 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 31.4 KB
#        id  job_satisfaction_rate
# 0  100298                   0.80
# 1  100480                   0.84
# 2  100503                   0.79
# 3  100610                   0.75
# 4  100692                   0.69

# %%
fig, axes = plt.subplots(figsize=(10,6))
test_target_job_satisfaction_rate['job_satisfaction_rate'].hist(bins=50)
plt.title('Распределение удовлетворенности сотрудников', fontsize=16)
plt.xlabel('Оценка удовлетворенности от 0 до 1', fontsize=13)
plt.ylabel('Количество сотрудников', fontsize=13)
plt.show()

# %% [markdown]
# Показатель распределен равномерно, есть пиковые значения ближе к 0,7.

# %% [markdown]
# #### Портрет довольного сотрудника

# %% [markdown]
# Возникла идея выделить из тренировочной сборки тех сотрудников, которые оценили свою удовлетворенность в промежутке между 0,7 и 1 и посмотреть, в каких отделах они работают, сколько получают и тд.
#
# Почему именно от 0,7: обычно, когда мы заполняем формы и нас просят оценить некий параметр от 0 до 10, обычно отметка 7 называется как-нибудь «выше среднего» или «хорошо».

# %%
# выделим из таблицы строки с оценками от 0,7
happy_emp = df[df["job_satisfaction_rate"].between(0.7, 1.0)]
happy_emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1108 entries, 1 to 3997
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     1108 non-null   int64
#  1   dept                   1106 non-null   object
#  2   level                  1108 non-null   object
#  3   workload               1108 non-null   object
#  4   employment_years       1108 non-null   int64
#  5   last_year_promo        1108 non-null   object
#  6   last_year_violations   1108 non-null   object
#  7   supervisor_evaluation  1108 non-null   int64
#  8   salary                 1108 non-null   int64
#  9   job_satisfaction_rate  1108 non-null   float64
# dtypes: float64(1), int64(4), object(5)
# memory usage: 95.2+ KB

# %% [markdown]
# 1108 строк из 4000 — это строки с оценкой удовлетворенности от 0,7. Выходит, примерно четверть сотрудников в целом довольны работой в компании. Давайте рассмотрим эти данные подробнее: построим графики.

# %%
# построим графики
fig, axes = plt.subplots(figsize=(10,6))
plt.title('Распределение признака «Длительность работы в компании»', fontsize=16)
sns.countplot(x = 'employment_years', data = happy_emp, palette='pastel')
plt.xlabel('Количество проработанных лет', fontsize=13)
plt.ylabel('Количество сотрудников', fontsize=13)
plt.show()

# %% [markdown]
# Большинство довольных сотрудников проработало в компании 2 года. На втором месте — те, кто проработал 5 лет.

# %%
fig, axes = plt.subplots(figsize=(10,6))
plt.title('Распределение признака «Оценка качества работы»', fontsize=16)
sns.countplot(x = 'supervisor_evaluation', data = happy_emp, palette='pastel')
plt.xlabel('Оценка, которую выставил руководитель', fontsize=13)
plt.ylabel('Количество сотрудников', fontsize=13)
plt.show()

# %% [markdown]
# Большая часть довольных сотрудников получили от руководителей «четверки»: при этом никто из них не получал оценки ниже «тройки», а «тройку» — очень малая часть.

# %%
# оценим соотношение категориальных признаков 
cat_col_happy_emp = ['dept', 'level', 'workload', 'last_year_promo', 'last_year_violations']

# %%
# построим круговые диаграммы
i = 1
plt.figure(figsize=(18,15))
for name in cat_col_happy_emp:
    pie_graph(happy_emp, name, 'id', len(cat_col_happy_emp), i)
    i += 1

# %% [markdown]
# Среди довольных сотрудников лидируют продажники и технари, в плане распределения по грейдам и загруженности особых отличий от общей картины нет, но мы видим, что среди тех, кто доволен, чуть больше людей получили повышение — незначительно, но все же. Также, лишь 2% этих сотрудников нарушали трудовой договор.

# %%
# посмотрим на график распределения зарплаты
fig, axes = plt.subplots(figsize=(10,6))
happy_emp['salary'].hist(bins=50)
plt.title('Распределение зарплат в компании', fontsize=16)
plt.xlabel('Размер зарплаты', fontsize=13)
plt.ylabel('Количество сотрудников', fontsize=13)
plt.show()

# %% [markdown]
# Большинство довольных сотрудников получает около 25-30 тысяч — тут без изменений.

# %%
# посмотрим на график распределения удовлетворенности
fig, axes = plt.subplots(figsize=(10,6))
happy_emp['job_satisfaction_rate'].hist(bins=50)
plt.title('Уровень удовлетворенности сотрудников', fontsize=16)
plt.xlabel('Оценка удовлетворенности от 0 до 1', fontsize=13)
plt.ylabel('Количество сотрудников', fontsize=13)
plt.show()

# %% [markdown]
# Видим, что в этом диапазоне распределение признака смещено влево — все-таки мало кто поставил твердую 1.

# %% [markdown]
# <span style="color: blue; font-weight: bold">Комментарий ревьюера : </span> ✔️\
# <span style="color: green"> 👍</span>

# %% [markdown]
# #### Матрица корреляции

# %% [markdown]
# В таблице есть и дискретные и категориальные признаки — хорошим решением будет использование матрицы `phik` - она анализирует корреляцию между признаками любого типа и не требует предварительного кодирования.

# %%
# превратим столбец id в индекс датасета — он не должен участвовать в анализе корреляций
df = df.set_index('id')

# %%
# теперь найдем дубликаты, которые появились из-за того, что не стало столбца id
df.duplicated().sum()
# Out:
# 248

# %%
# и удалим эти дубликаты
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ⚠️\
# <font color='darkorange'>Так как мы удалили признак "id" с неповторяющимися значениями, у нас могут появиться новые явные дубликаты: чем меньше признаков остаётся, тем выше шанс, что значения остальных признаков будут пересекаться. При этом ценности для модели такие наблюдения уже не принесут, поэтому стоит проверить дубликаты также в финальной версии обучающей таблицы.</font>

# %% [markdown]
# <div class="alert alert-info">
#
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
#
#
# Поняла, спасибо. Но в моем восприятии объекты с разными id при правильной выгрузке не должны быть дубликатами. Ведь могут, например, быть два "одинаковых" по параметрам сотрудника, но разные люди фактически. Разве количество таких данных не имеет значение? Допустим, если не имеет для модели — но ведь при построении графиков и оценке процентного соотношения признаков количество строк с данными имеет значение.
#
# </div>

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера 2: </b></font> \
# <font color='blue'> Эти данные не несут новой информации в модель, но вносят неоправданные смещения и увеличивают вычислительную нагрузку.\
# Разные id в модел не подаютя.</font>

# %% [markdown]
# <div class="alert alert-info">
#
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
#
#
# Хорошо, удалила.
#
# </div>

# %% [markdown]
# <span style="color: blue; font-weight: bold">Комментарий ревьюера 2: </span> ✔️\
# <span style="color: green">👍</span>

# %%
corr_matrix = df.phik_matrix(interval_cols=['salary', 'job_satisfaction_rate'])
plt.figure(figsize=(13, 10))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Матрица корреляции признаков')
plt.show()

# %% [markdown]
# Имеется высокая корреляция между:
#
# - уровнем занимаемой должности и длительностью работы в компании;
# - уровнем занимаемой должности и зарплатой;
# - уровнем загруженности сотрудника и зарплатой;
# - целевым признаком и оценкой качества работы;
# - целевым признаком и нарушениями трудового договора.
#
# Первые три пункта в списке высоких корреляций логичны — длительность работы влияет обычно на повышение по службе, а зарплата в идеальном мире напрямую зависит от должности и загрузки. Мультиколлениарности не наблюдаем.

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера : </b></font> ✔️\
# <font color='green'>Здорово,что применена `phik` для анализа и нелинейных зависимостей</font>

# %% [markdown]
# Построим графики и посмотрим, насколько они будут показательны.

# %%
fig = plt.figure(figsize=(10,8))
sns.scatterplot(data=df, y='employment_years', x='job_satisfaction_rate')
plt.xlabel('Насколько доволен сотрудник, от 0 до 1')
plt.ylabel('Количество отработанных лет')
plt.title('Взаимное распределение признаков «удовлетворенность» и «количество лет в компании»')
plt.show()

# %% [markdown]
# Видим, что большая часть значений удовлетворенности между 0,9 и 1 — это отметки людей, проработавших в компании от пяти лет. Люди, которые проработали меньше пяти лет, активнее говорят о своей низкой удовлетворенности.

# %%
fig = plt.figure(figsize=(10,8))
sns.scatterplot(data=df, y='supervisor_evaluation', x='job_satisfaction_rate')
plt.xlabel('Насколько доволен сотрудник, от 0 до 1')
plt.ylabel('Оценка работы сотрудника руководителем')
plt.title('Взаимное распределение признаков «удовлетворенность» и «оценка от руководства»')
plt.show()

# %% [markdown]
# Признаки распределены логично: низкая оценка, полученная от руководства компании, провоцирует недовольство сотрудника, высокая — отличный механизм социального поглаживания.

# %% [markdown]
# На этом этапе мы проанализировали данные, визуализировали их. Выяснили вот такие особенности о сотрудниках компании:
# - большинство работают в компании 1-3 года;
# - получают от руководителей преимущественно «тройки» и «четверки»;
# - по количеству лидируют представители отдела продаж, на втором месте — сотрудники технического/технологического подразделения,   на третьем — отдела закупок;
# - десятая часть — это сеньоры, остальные поровну — это джуны и мидлы;
# - пятая часть сотрудников перегружена, треть — недогружены;
# - повышениями людей не балуют;
# - 14% сотрудников нарушала договор;
# - большинство получают от 20 до 35 тысяч.
#
# Когда мы рассмотрели только тех сотрудников, кто поставил оценку ближе к максимальной, мы выяснили, что они получали преимущественно положительную оценку от руководства, проработали 2 или 5 лет в компании, их чуть чаще повышали и очень малая часть из них допускала нарушение трудового договора.
#
#
# На основе этих данных можно предположить, что есть связь между уровнем удовлетворенности и такими факторами, как стаж работы, оценка руководителя, загрузка и перспектива повышения.

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ✔️\
# <font color='green'>Хорошая работа в части исследования данных: молодец, что используешь функции, а также применяешь подходящие для типов данных инструменты.</font>

# %% [markdown]
# ### Шаг 4. Подготовка данных

# %% [markdown]
# Выполним подготовку признаков в пайплайне, дополнив пайплайн шага предобработки. Используем разные кодировщики.

# %% [markdown]
# #### Пайплайн

# %%
# создание тренировочной выборки входных признаков и целевого признака
X_train = df.drop('job_satisfaction_rate', axis=1)
y_train = df['job_satisfaction_rate']
X_test = test_features.drop('id', axis=1)
y_test = test_target_job_satisfaction_rate['job_satisfaction_rate']

RANDOM_STATE = 100
TEST_SIZE = 0.25
stratify = y_test

# %%
X_train.head()
# Out:
#               dept   level workload  employment_years last_year_promo  \
# id
# 155278       sales  junior   medium                 2              no
# 653870          hr  junior     high                 2              no
# 184592       sales  junior      low                 1              no
# 171431  technology  junior      low                 4              no
# 693419          hr  junior   medium                 1              no
#
#        last_year_violations  supervisor_evaluation  salary
# id
# 155278                   no                      1   24000
# 653870                   no                      5   38400
# 184592                   no                      2   12000
# 171431                   no                      2   18000
# 693419                   no                      3   22800

# %% [markdown]
# Поскольку целевой признак представляет собой непрерывную числовую переменную, то стоит использовать модели линейной регресии и дерево решений для задач регресии.

# %%
#создание списков переменных датасета X_train
num_col = ['employment_years', 
           'supervisor_evaluation', 
           'salary']

ord_col = ['level',
           'workload']                      

ohe_col = ['dept',
           'last_year_promo',
           'last_year_violations']

# %% [markdown]
# <span style="color: blue; font-weight: bold">Комментарий ревьюера : </span> ⚠️\
# <span style="color: darkorange">'level' и 'workload' вполне порядковые признаки. Не стоит "раздувать" количество столбцов во входных данных моделей.</span>

# %% [markdown]
# <div class="alert alert-info">
#
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
#
#
# Я провела эксперимент и унесла их в порядковые — а в итоге метрика SMAPE улетела за 18 (под 17 на тестовой). Подскажи, пожалуйста, нужно ли было что-то еще поменять, помимо добавления новых категорий в соответствующий пайплайн?
#
# </div>

# %% [markdown]
# <span style="color: blue; font-weight: bold">Комментарий ревьюера 2: </span> ⚠️\
# <span style="color: darkorange"> Указать порядок этих порядковых признаков для Энкодера.</span>

# %% [markdown]
# <div class="alert alert-info">
#
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
#
#
# Спасибо, в итоге все наладилось.
#
# </div>

# %% [markdown]
# <span style="color: blue; font-weight: bold">Комментарий ревьюера 2: </span> ✔️\
# <span style="color: green">👍</span>

# %%
# пайплайн для кодирования категориальных признаков
ohe_pipe = Pipeline(
    [
        ('simpleImputer_ohe', 
         SimpleImputer(missing_values=np.nan, 
                       strategy='most_frequent')), 
        ('ohe', 
         OneHotEncoder(drop='first', 
                       handle_unknown='ignore', 
                       ))
    ]
)

# %%
# пайплайн для кодирования категориальных ранговых признаков
ord_pipe = Pipeline(
    [('simpleImputer_before_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent')),
     ('ord',  OrdinalEncoder(
                categories=[
                    ['junior', 'middle', 'senior'],
                    ['low', 'medium', 'high']
                ], 
                handle_unknown='use_encoded_value', unknown_value=np.nan
            )
        ),
     ('simpleImputer_after_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent'))
    ]
)

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера : </b></font> ✔️\
# <font color='green'> Здорово, что есть обработка неизвестых категорий (можно не удалять `'_'` вручную из тестовых данных.)</font>

# %%
# пайплайн для подготовки данных
data_preprocessor = ColumnTransformer(
    [
        ('ohe', ohe_pipe, ohe_col),
        ('ord', ord_pipe, ord_col),
        ('num', StandardScaler(), num_col)
    ], 
    remainder='passthrough'
)

# %%
# итоговый пайплайн: подготовка данных и модель
pipe_final = Pipeline([
    ('preprocessor', data_preprocessor),
    ('models', DecisionTreeRegressor(random_state=RANDOM_STATE))
])

# %% [markdown]
# Данные подготовлены — теперь обучим модели.

# %% [markdown]
# <span style="color: blue; font-weight: bold">Комментарий ревьюера : </span> ✔️\
# <span style="color: green"> 👍</span>

# %% [markdown]
# ### Шаг 5. Обучение моделей

# %% [markdown]
# Обучим две модели: линейную модель и дерево решений.

# %%
# параметры для передачи GridSearchCV для поиска оптимальной модели 
# с разными Scaler и Encoder и перебором гиперпараметров

param_distributions = [
    {
        'models': [DecisionTreeRegressor(random_state=RANDOM_STATE)],
        'models__max_depth': range(2, 21),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    },
    {
        'models': [LinearRegression()],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    }, 
]

# %%
# создание собственной метрики для оценки модели

def SMAPE(y_true, y_pred):
    return 100 / len(y_true) * np.sum(2 * np.abs(y_true - y_pred) / ((np.abs(y_true) + np.abs(y_pred))))
                                      
SMAPE_score = make_scorer(SMAPE, greater_is_better=False)

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ✔️\
# <font color='green'> `smape` расчитана верно.</font>

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера : </b></font> ✔️ <br>
# <font color='green'>Верно, что не забываешь указать greater_is_better=False, Это пригодится для SearchCV. SMAPE — ошибка, её минимизируем.</font>

# %%
# поиск оптимальной модели с перебором гиперпараметров
grid = GridSearchCV(
    pipe_final, 
    param_grid=param_distributions, 
    cv=5, 
    scoring=SMAPE_score, 
    n_jobs=-1, 
)

# обучение модели на тренировочной выборке
grid.fit(X_train, y_train);

# %%
print('Метрика SMAPE для лучшей модели:\n', round(-grid.best_score_, 2)) 
print('\nЛучшая модель и её параметры:\n\n', grid.best_params_)
# Out:
# Метрика SMAPE для лучшей модели:
#  15.76
#
# Лучшая модель и её параметры:
#
#  {'models': DecisionTreeRegressor(random_state=100), 'models__max_depth': 13, 'preprocessor__num': MinMaxScaler()}

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера : </b></font> ✔️\
# <font color='green'>Подбор гиперпараметров проведён верно. Использована целевая метрика, направление отбора верное ).</font>

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ❌\
# <font color='red'> ~~Нужно вывести результаты оценки Топ-10 лучших моделей, для анализа.<~~/font>

# %% [markdown]
# <div class="alert alert-info">
#
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
#
#
# Вывела ниже. Но пока не понимаю, как проанализировать полученную таблицу — помоги, пожалуйста. Я не могу развернуть столбцы и полностью увидеть данные. Почему-то `pd.set_option('display.max_columns', None)` не срабатывает.
#
# </div>

# %% [markdown]
# <span style="color: blue; font-weight: bold">Комментарий ревьюера 2: </span> ⚠️\
# <span style="color: darkorange"> `pd.set_option('display.max_columns', None)` - показвает неограниченное количество столбцов в Датафрейме.\
# Для полного вывода данных в столбце, нужен `pd.set_option('display.max_colwidth', None)`</span>

# %% [markdown]
# <div class="alert alert-info">
#
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# Спасибо, теперь отлично.
#
# </div>

# %% [markdown]
# <span style="color: blue; font-weight: bold">Комментарий ревьюера 2: </span> ✔️\
# <span style="color: green">👍</span>

# %%
# посмотрим на результаты десяти лучших моделей
# Выведем результаты в виде датафрейм
pd.set_option('display.max_colwidth', None)
pd.DataFrame(grid.cv_results_)[
    ['std_test_score', 'rank_test_score', 'param_models', 'mean_test_score','params']
].sort_values('rank_test_score').head(10)
# Out:
#     std_test_score  rank_test_score                             param_models  \
# 34        0.738918                1  DecisionTreeRegressor(random_state=100)
# 33        0.746779                2  DecisionTreeRegressor(random_state=100)
# 35        0.736742                3  DecisionTreeRegressor(random_state=100)
# 30        0.701167                4  DecisionTreeRegressor(random_state=100)
# 31        0.796265                5  DecisionTreeRegressor(random_state=100)
# 32        0.759864                6  DecisionTreeRegressor(random_state=100)
# 39        0.587421                7  DecisionTreeRegressor(random_state=100)
# 40        0.593774                8  DecisionTreeRegressor(random_state=100)
# 54        0.596650                9  DecisionTreeRegressor(random_state=100)
# 41        0.635535               10  DecisionTreeRegressor(random_state=100)
#
#     mean_test_score  \
# 34       -15.756661
# 33       -15.768414
# 35       -15.789152
# 30       -15.798478
# ...

# %% [markdown]
# В топ-три вошли модели с глубиной 13, использующие MinMaxScaler, StandardScaler и параметр passthrough, соответственно.

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера 2: </b></font> ✔️\
# <font color='green'> Отлично, что есть табличка результатов для сравнения.</font>

# %%
y_pred = grid.predict(X_test)
y_true = y_test
print(f'Метрика SMAPE на тестовой выборке: {round(SMAPE(y_true, y_pred), 2)}')
# Out:
# Метрика SMAPE на тестовой выборке: 14.54

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ✔️\
# <font color='green'>Тестирование проведено верно.</font>

# %%
# поиск важных признаков
X_encoded = grid.best_estimator_['preprocessor'].fit_transform(X_train)

#model = grid.best_estimator_['models'].fit(X_encoded, y_train)
#explainer = shap.PermutationExplainer(model, X_encoded)


labels = grid.best_estimator_[:-1].get_feature_names_out()

plt.title('Агрегированный вклад признаков в прогнозы модели', fontsize=18)
plt.ylabel('Исследуемые признаки', fontsize=14)
shap.summary_plot(X_encoded, plot_type='bar', feature_names=labels)

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ⚠️\
# <font color='darkorange'> Препроцессор и модель в `grid.best_estimator_` уже обученные.</font>

# %% [markdown]
# <div class="alert alert-info">
#
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
#
#
# Спасибо, скрыла ненужное.
#
# </div>

# %% [markdown]
# <span style="color: blue; font-weight: bold">Комментарий ревьюера 2: </span> ✔️\
# <span style="color: green"> 👍 препроцессор, то же, обученный )).</span>

# %% [markdown]
# Что же мы видим: самые важные для модели признаки — загрузка сотрудника, уровень его должности и оценка, выставленная руководителем.

# %% [markdown]
# <span style="color: blue; font-weight: bold">Комментарий ревьюера : </span> ✔️\
# <span style="color: green"> 👍</span>

# %% [markdown]
# ### Шаг 6. Выводы

# %% [markdown]
# Мы достигли критерия успеха: метрика SMAPE на тестовой выборке показала ≤15. Лучше всего справилась модель регрессии на основе деревьев решений с глубиной равной 13, в которой в качестве масштабирования количественных признаков используется MinMaxScaler.
# Полученный результат указывает на хорошую способность модели к обобщению и прогнозированию на новых данных. Разница между показателями на тренировочной и тестовой выборке невелика, что является хорошим индикатором отсутствия переобучения.

# %% [markdown]
# <span style="color: blue; font-weight: bold">Комментарий ревьюера : </span> ✔️\
# <span style="color: green"> 👍</span>

# %% [markdown]
# ## Задача 2: Предсказание увольнения сотрудника из компании

# %% [markdown]
# Для этой задачи мы используем те же входные признаки, что и в предыдущей задаче. Однако целевой признак отличается: это quit — факт увольнения сотрудника из компании.

# %% [markdown]
# ### Шаг 1. Загрузка данных

# %%
train_quit = pd.read_csv('https://code.s3.yandex.net/datasets/train_quit.csv')
train_quit.info()
train_quit.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     4000 non-null   int64
#  1   dept                   4000 non-null   object
#  2   level                  4000 non-null   object
#  3   workload               4000 non-null   object
#  4   employment_years       4000 non-null   int64
#  5   last_year_promo        4000 non-null   object
#  6   last_year_violations   4000 non-null   object
#  7   supervisor_evaluation  4000 non-null   int64
#  8   salary                 4000 non-null   int64
#  9   quit                   4000 non-null   object
# dtypes: int64(4), object(6)
# memory usage: 312.6+ KB
#        id        dept   level workload  employment_years last_year_promo  \
# 0  723290       sales  middle     high                 2              no
# ...

# %%
test_target_quit = pd.read_csv('https://code.s3.yandex.net/datasets/test_target_quit.csv')
test_target_quit.info()
test_target_quit.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      2000 non-null   int64
#  1   quit    2000 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 31.4+ KB
#        id quit
# 0  999029  yes
# 1  372846   no
# 2  726767   no
# 3  490105   no
# 4  416898  yes

# %% [markdown]
# ### Шаг 2. Предобработка данных

# %% [markdown]
# #### Явные дубликаты

# %% [markdown]
# Проверим явные дубликаты.

# %%
train_quit.duplicated().sum()
# Out:
# 0

# %%
test_target_quit.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Неявные дубликаты

# %% [markdown]
# Явных дубликатов нет, поищем неявные.

# %%
# сначала в тренировочной выборке
train_quit['dept'].unique()
# Out:
# array(['sales', 'purchasing', 'marketing', 'technology', 'hr'],
#       dtype=object)

# %%
train_quit['level'].unique()
# Out:
# array(['middle', 'junior', 'sinior'], dtype=object)

# %%
# исправим опечатку
train_quit['level'] = train_quit['level'].replace('sinior','senior')
# проверим
train_quit['level'].unique()
# Out:
# array(['middle', 'junior', 'senior'], dtype=object)

# %%
train_quit['workload'].unique()
# Out:
# array(['high', 'medium', 'low'], dtype=object)

# %%
train_quit['employment_years'].unique()
# Out:
# array([ 2,  5,  1,  8,  4,  7,  3,  9,  6, 10])

# %%
train_quit['last_year_promo'].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
train_quit['last_year_violations'].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
train_quit['supervisor_evaluation'].unique()
# Out:
# array([4, 1, 3, 5, 2])

# %%
train_quit['last_year_violations'].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
# теперь в таблице с целевым признаком
test_target_quit['quit'].unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %% [markdown]
# #### Пропуски

# %% [markdown]
# Поищем пропуски в таблицах.

# %%
train_quit.isna().sum()
# Out:
# id                       0
# dept                     0
# level                    0
# workload                 0
# employment_years         0
# last_year_promo          0
# last_year_violations     0
# supervisor_evaluation    0
# salary                   0
# quit                     0
# dtype: int64

# %%
test_features.isna().sum()
# Out:
# id                       0
# dept                     0
# level                    0
# workload                 0
# employment_years         0
# last_year_promo          0
# last_year_violations     0
# supervisor_evaluation    0
# salary                   0
# dtype: int64

# %%
test_target_quit.isna().sum()
# Out:
# id      0
# quit    0
# dtype: int64

# %% [markdown]
# Тут пропусков нет.

# %% [markdown]
# <span style="color: blue; font-weight: bold">Комментарий ревьюера : </span> ✔️\
# <span style="color: green"> 👍</span>

# %% [markdown]
# ### Шаг 3. Исследовательский анализ данных

# %% [markdown]
# Проведем исследовательский анализ данных: построим графики, визуализируем данные, составим портрет уволившегося сотрудника, сравним зарплатные достижения, а также уровень удовлетворенности уволившихся и оставшихся сотрудников.

# %% [markdown]
# #### Графики для таблицы train_quit

# %%
train_quit.info()
train_quit.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     4000 non-null   int64
#  1   dept                   4000 non-null   object
#  2   level                  4000 non-null   object
#  3   workload               4000 non-null   object
#  4   employment_years       4000 non-null   int64
#  5   last_year_promo        4000 non-null   object
#  6   last_year_violations   4000 non-null   object
#  7   supervisor_evaluation  4000 non-null   int64
#  8   salary                 4000 non-null   int64
#  9   quit                   4000 non-null   object
# dtypes: int64(4), object(6)
# memory usage: 312.6+ KB
#        id        dept   level workload  employment_years last_year_promo  \
# 0  723290       sales  middle     high                 2              no
# ...

# %% [markdown]
# Рассмотрим дискретные признаки.

# %%
fig, axes = plt.subplots(figsize=(10,6))
plt.title('Распределение признака «Длительность работы в компании»', fontsize=16)
sns.countplot(x = 'employment_years', data = train_quit, palette='pastel')
plt.xlabel('Количество проработанных лет', fontsize=13)
plt.ylabel('Количество сотрудников', fontsize=13)
plt.show()

# %% [markdown]
# Большинство сотрудников проработали 1-2 года.

# %%
fig, axes = plt.subplots(figsize=(10,6))
plt.title('Распределение признака «Оценка качества работы»', fontsize=16)
sns.countplot(x = 'supervisor_evaluation', data = train_quit, palette='pastel')
plt.xlabel('Оценка, которую выставил руководитель', fontsize=13)
plt.ylabel('Количество сотрудников', fontsize=13)
plt.show()

# %% [markdown]
# Самые популярные оценки, полученная сотрудниками — 3 и 4.

# %% [markdown]
# Теперь рассмотрим категориальные признаки.

# %%
# напишем функцию для построения диаграмм
def pie_graph(dataset, column, name, n, i):
    plt.subplot(1, n, i)
    plt.title(column)
    plt.pie(x=dataset.groupby(column)[name].count(),
            startangle=90,
            labeldistance=1.1, 
            wedgeprops={'linewidth':3, 'edgecolor':'white'}, 
            autopct='%1.1f%%',
            labels=dataset.groupby(column)[name].count().index, 
            colors=sns.color_palette('BuPu_r'))

# %%
# перечислим нужные признаки  
cat_col_train_quit = ['dept', 'level', 'workload', 'last_year_promo', 'last_year_violations', 'quit']

# %%
# построим круговые диаграммы
i = 1
plt.figure(figsize=(18,15))
for name in cat_col_train_quit:
    pie_graph(train_quit, name, 'id', len(cat_col_train_quit), i)
    i += 1

# %% [markdown]
# Среди тех, кто заполнил анкету, лидируют представители отдела продаж, на втором месте — сотрудники технического/технологического подразделения, на третьем — отдела закупок.
# Примерно поровну отметилось джуниоров и мидлов, примерно 9% считаются сениорами.
# Больше половины сотрудников загружены средне, треть — недогружены, остальным грозит выгорание.
# Практически никого не повысили в прошедшем году, седьмая часть сотрудников нарушала договор.
#
# Уволилась треть.

# %% [markdown]
# Рассмотрим количественные признаки.

# %%
fig, axes = plt.subplots(figsize=(10,6))
train_quit['salary'].hist(bins=50)
plt.title('Распределение зарплат в компании', fontsize=16)
plt.xlabel('Размер зарплаты', fontsize=13)
plt.ylabel('Количество сотрудников', fontsize=13)
plt.show()

# %% [markdown]
# Пиковые показатели зарплаты — в промежутке между 25 и 30 тысячами.

# %% [markdown]
# #### График для таблицы test_target_quit

# %%
# перечислим нужные признаки  
cat_col_test_target_quit = ['quit']

# %%
# построим круговую диаграмму
i = 1
plt.figure(figsize=(8,6))
for name in cat_col_test_target_quit:
    pie_graph(test_target_quit, name, 'id', len(cat_col_test_target_quit), i)
    i += 1

# %% [markdown]
# Таблицу с входными данными тренировочной выборки на этом шаге анализировать не будем — это уже сделано в пункте 1.4.2

# %% [markdown]
# <span style="color: blue; font-weight: bold">Комментарий ревьюера : </span> ✔️\
# <span style="color: green"> 👍</span>

# %% [markdown]
# #### Портрет уволившегося сотрудника

# %% [markdown]
# Составим портрет «уволившегося сотрудника». Например, можно узнать, в каком отделе с большей вероятностью работает уволившийся сотрудник и какой у него уровень загруженности. Также можно сравнить среднее значение зарплаты ушедших сотрудников с теми, кто остался в компании.

# %%
# создадим новый датасет и унесем в него данные о тех, кто покинул компанию
got_quit = train_quit.query('quit == "yes"')
got_quit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1128 entries, 3 to 3999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     1128 non-null   int64
#  1   dept                   1128 non-null   object
#  2   level                  1128 non-null   object
#  3   workload               1128 non-null   object
#  4   employment_years       1128 non-null   int64
#  5   last_year_promo        1128 non-null   object
#  6   last_year_violations   1128 non-null   object
#  7   supervisor_evaluation  1128 non-null   int64
#  8   salary                 1128 non-null   int64
#  9   quit                   1128 non-null   object
# dtypes: int64(4), object(6)
# memory usage: 96.9+ KB

# %% [markdown]
# В таблице с тренировочной выборкой 4000 строк — выходит, что уволилась четвертая часть сотрудников, которые заполняли анкету.

# %% [markdown]
# Сначала построим графики для датасета, в котором только уволившиеся сотрудники — а затем посмотрим данные в сравнении.

# %%
fig, axes = plt.subplots(figsize=(10,6))
plt.title('Распределение признака «Длительность работы в компании»', fontsize=16)
sns.countplot(x = 'employment_years', data = got_quit, palette='pastel')
plt.xlabel('Количество проработанных лет', fontsize=13)
plt.ylabel('Количество сотрудников', fontsize=13)
plt.show()

# %% [markdown]
# Первые кандидаты на увольнение — это люди, которые отработали год или два. Те, кто проработал 4-7 лет, увольняются гораздо реже. Среди тех, кто проработал 8-10 лет, практически никто не уходит (прямо как наши деды на заводах).

# %%
fig, axes = plt.subplots(figsize=(10,6))
plt.title('Распределение признака «Оценка качества работы»', fontsize=16)
sns.countplot(x = 'supervisor_evaluation', data = got_quit, palette='pastel')
plt.xlabel('Оценка, которую выставил руководитель', fontsize=13)
plt.ylabel('Количество сотрудников', fontsize=13)
plt.show()

# %% [markdown]
# Уволившиеся сотрудники получали все виды оценок, но самая распространенная — 3.

# %%
# оценим соотношение категориальных признаков 
cat_col_got_quit = ['dept', 'level', 'workload', 'last_year_promo', 'last_year_violations']

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ❌\
# <font color='red'> ~~Распределение категорий в данных неравномерное, поэтому нужно нормализовать количество ушедших относительно исследуемого признака, Например из какого департамента уходят чаще, оносительно количества работающих в департаменте.\
# Сделать это можно сгруппировав данные по признаку и посчитать долю таргета в каждом из значений~~ (`.groupby(['dept'])['quit'].value_counts(normalize=True)`)</font>

# %% [markdown]
# <div class="alert alert-info">
#
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
#
#
# Точно, спасибо! Ведь это важно — понять, как распределяется целевой признак внутри категории. Сделала ниже.
#
# </div>

# %% [markdown]
# <span style="color: blue; font-weight: bold">Комментарий ревьюера 2: </span> ✔️\
# <span style="color: green"> 👍</span>

# %% [markdown]
# <span style="color: blue; font-weight: bold">Комментарий ревьюера : </span> ⚠️\
# <span style="color: darkorange"> Срез по мультииндексу можно делать так: </span>
# ```python
# df.loc[df.index.get_level_values(1) == 'yes']
# ```

# %%
# построим круговые диаграммы
i = 1
plt.figure(figsize=(18,15))
for name in cat_col_got_quit:
    pie_graph(got_quit, name, 'id', len(cat_col_got_quit), i)
    i += 1

# %% [markdown]
# Распределение по отделам уже знакомо: лидируют продажники и представители технических профессий — их в принципе больше. Среди уволившихся почти 90% — начинающие специалисты, примерно десятая часть — средний уровень. Десятая часть уволившихся была перегружена работой, а осташиеся распределились пополам: загружены средне и недогружены. Процент тех, кто получил повышение в прошлом году, мизерный. 4/5 в прошлом году нарушили трудовой договор.

# %% [markdown]
# Распределение категорий в данных неравномерное, поэтому нужно нормализовать количество ушедших относительно исследуемого признака: например из какого департамента уходят чаще, оносительно количества работающих в департаменте. Рассмотрим распределение целевого признака в рамках каждой категории.

# %%
train_quit.groupby(['dept'])['quit'].value_counts(normalize=True)
# Out:
# dept        quit
# hr          no      0.750000
#             yes     0.250000
# marketing   no      0.719931
#             yes     0.280069
# purchasing  no      0.717687
#             yes     0.282313
# sales       no      0.716968
#             yes     0.283032
# technology  no      0.702586
#             yes     0.297414
# Name: quit, dtype: float64

# %% [markdown]
# Из отдела кадров ушла 1/4 сотрудников, из маркетингового, отдела закупок, продаж и технологий — 1/3.

# %%
train_quit.groupby(['level'])['quit'].value_counts(normalize=True)
# Out:
# level   quit
# junior  yes     0.514623
#         no      0.485377
# middle  no      0.936246
#         yes     0.063754
# senior  no      0.952381
#         yes     0.047619
# Name: quit, dtype: float64

# %% [markdown]
# Уходит примерно половина сотрудников начального уровня, среди сотрудников среднего и высшего звена соотношение 6% и 5% соответственно.

# %%
train_quit.groupby(['workload'])['quit'].value_counts(normalize=True)
# Out:
# workload  quit
# high      no      0.820475
#           yes     0.179525
# low       no      0.570364
#           yes     0.429636
# medium    no      0.769594
#           yes     0.230406
# Name: quit, dtype: float64

# %% [markdown]
# Среди тех, кто перегружен, уходит примерно пятая часть, среди тех, кто низко — немного меньше половины. Среди тех, у кого загрузка средняя — примерно четвертая часть.

# %%
train_quit.groupby(['last_year_promo'])['quit'].value_counts(normalize=True)
# Out:
# last_year_promo  quit
# no               no      0.710059
#                  yes     0.289941
# yes              no      0.991150
#                  yes     0.008850
# Name: quit, dtype: float64

# %% [markdown]
# Среди тех, кого в прошлом году не повысили, уволилась почти треть. Среди тех, кого повысили — почти никто.

# %%
train_quit.groupby(['last_year_violations'])['quit'].value_counts(normalize=True)
# Out:
# last_year_violations  quit
# no                    no      0.739508
#                       yes     0.260492
# yes                   no      0.581651
#                       yes     0.418349
# Name: quit, dtype: float64

# %% [markdown]
# Среди тех, кто нарушил договор в прошлом году, ушло 40%, среди тех, кто не нарушил — меньше трети.

# %%
# посмотрим на график распределения зарплаты
fig, axes = plt.subplots(figsize=(10,6))
got_quit['salary'].hist(bins=50)
plt.title('Распределение зарплат в компании', fontsize=16)
plt.xlabel('Размер зарплаты', fontsize=13)
plt.ylabel('Количество сотрудников', fontsize=13)
plt.show()

# %% [markdown]
# На этом графике стало понятнее, что большинство уволившихся получали от 12 до 23-24 тысяч — это ниже, чем средняя зарплата по компании.

# %% [markdown]
# <span style="color: blue; font-weight: bold">Комментарий ревьюера : </span> ✔️\
# <span style="color: green"> 👍</span>

# %% [markdown]
# Теперь рассмотрим графики, построенные на основе общей таблицы — с уволенными и оставшимися.

# %%
fig, axes = plt.subplots(figsize=(8,6))
plt.title('Сколько лет обычно отрабатывают перед увольнением',  fontsize=14)
sns.countplot(x = 'employment_years', data = train_quit, palette='pastel', hue='quit')
plt.xlabel('Количество отработанных лет', fontsize=13)
plt.ylabel('Количество сотрудников', fontsize=13)
plt.show()

# %%
quit_percentage = (got_quit['employment_years'].value_counts(normalize=True) * 100)
quit_percentage.rename_axis('employment_years').reset_index(name='percentage')
# Out:
#    employment_years  percentage
# 0                 1   53.102837
# 1                 2   25.709220
# 2                 3   14.450355
# 3                 4    2.393617
# 4                 5    2.039007
# 5                 6    0.886525
# 6                 7    0.620567
# 7                 8    0.265957
# 8                 9    0.265957
# 9                10    0.265957

# %% [markdown]
# Картина уже знакомая, но еще подкрепим ее процентами — 53% уволившихся отработали только год, четвертая часть — два.

# %%
fig, axes = plt.subplots(figsize=(8,6))
plt.title('Влияют ли оценки от руководства на вероятность увольнения',  fontsize=14)
sns.countplot(x = 'supervisor_evaluation', data = train_quit, palette='pastel', hue='quit')
plt.xlabel('Оценка, выставленная руководителем', fontsize=13)
plt.ylabel('Количество сотрудников', fontsize=13)
plt.show()

# %%
evaluation_percentage = got_quit['supervisor_evaluation'].value_counts(normalize=True) * 100
evaluation_percentage.rename_axis('supervisor_evaluation').reset_index(name='percentage')
# Out:
#    supervisor_evaluation  percentage
# 0                      3   46.365248
# 1                      4   25.354610
# 2                      2   14.539007
# 3                      1    8.421986
# 4                      5    5.319149

# %% [markdown]
# Почти половина уволившихся получили «тройку» от руководства — и только 5% получили «пятерку». Меж тем среди оставшихся самая популярная оценка — 4.

# %%
fig, axes = plt.subplots(figsize=(8,6))
plt.title('В каком отделе больше всего увольнений',  fontsize=14)
sns.countplot(x = 'dept', data = train_quit, palette='pastel', hue='quit')
plt.xlabel('Отдел', fontsize=13)
plt.ylabel('Количество сотрудников', fontsize=13)
plt.show()

# %%
evaluation_percentage = got_quit['dept'].value_counts(normalize=True) * 100
evaluation_percentage.rename_axis('dept').reset_index(name='percentage')
# Out:
#          dept  percentage
# 0       sales   36.081560
# 1  technology   24.468085
# 2  purchasing   14.716312
# 3   marketing   14.450355
# 4          hr   10.283688

# %% [markdown]
# Это мы уже видели: лидирует отдел продаж — и среди уволившихся и среди оставшихся.

# %%
fig, axes = plt.subplots(figsize=(8,6))
plt.title('Среди каких грейдов больше всего увольнений',  fontsize=14)
sns.countplot(x = 'level', data = train_quit, palette='pastel', hue='quit')
plt.xlabel('Грейд сотрудника', fontsize=13)
plt.ylabel('Количество сотрудников', fontsize=13)
plt.show()

# %%
evaluation_percentage = got_quit['level'].value_counts(normalize=True) * 100
evaluation_percentage.rename_axis('level').reset_index(name='percentage')
# Out:
#     level  percentage
# 0  junior   88.918440
# 1  middle    9.574468
# 2  senior    1.507092

# %% [markdown]
# Среди оставшихся лидирую мидлы, среди ушедших — джуны.

# %%
fig, axes = plt.subplots(figsize=(8,6))
plt.title('Влияет ли уровень загрузки сотрудника на увольнение',  fontsize=14)
sns.countplot(x = 'workload', data = train_quit, palette='pastel', hue='quit')
plt.xlabel('Уровень загруженности сотрудника', fontsize=13)
plt.ylabel('Количество сотрудников', fontsize=13)
plt.show()

# %%
evaluation_percentage = got_quit['workload'].value_counts(normalize=True) * 100
evaluation_percentage.rename_axis('workload').reset_index(name='percentage')
# Out:
#   workload  percentage
# 0      low   46.010638
# 1   medium   43.262411
# 2     high   10.726950

# %% [markdown]
# Интересно, что уходили люди и с небольшой загрузкой.

# %%
fig, axes = plt.subplots(figsize=(8,6))
plt.title('Общая картина повышений и увольнений',  fontsize=14)
sns.countplot(x = 'last_year_promo', data = train_quit, palette='pastel', hue='quit')
plt.xlabel('Повышали ли сотрудника в прошлом году', fontsize=13)
plt.ylabel('Количество сотрудников', fontsize=13)
plt.show()

# %%
evaluation_percentage = got_quit['last_year_promo'].value_counts(normalize=True) * 100
evaluation_percentage.rename_axis('last_year_promo').reset_index(name='percentage')
# Out:
#   last_year_promo  percentage
# 0              no   99.911348
# 1             yes    0.088652

# %% [markdown]
# Среди тех, кто уволился, повысили буквально одного человека.

# %%
fig, axes = plt.subplots(figsize=(8,6))
plt.title('Общая картина нарушений и увольнений',  fontsize=14)
sns.countplot(x = 'last_year_violations', data = train_quit, palette='pastel', hue='quit')
plt.xlabel('Нарушал ли сотрудник договор в прошлом году', fontsize=13)
plt.ylabel('Количество сотрудников', fontsize=13)
plt.show()

# %%
evaluation_percentage = got_quit['last_year_violations'].value_counts(normalize=True) * 100
evaluation_percentage.rename_axis('last_year_violations').reset_index(name='percentage')
# Out:
#   last_year_violations  percentage
# 0                   no   79.787234
# 1                  yes   20.212766

# %% [markdown]
# Пятая часть уволившихся нарушала договор.

# %%
fig, axes = plt.subplots(figsize=(8,6))
plt.title('Общая картина зарплат и уволнений',  fontsize=14)
sns.histplot(stat='density', common_norm=False, data=train_quit, x='salary', hue='quit')
plt.xlabel('Зарплата сотрудников', fontsize=13)
plt.ylabel('Плотность распределения', fontsize=13)
plt.show()

# %%
print('Средняя зарплата у уволившихся сотрудников:', round(train_quit.query('quit == "yes"')['salary'].mean(), 1))
print('Средняя зарплата у оставшихся сотрудников:', round(train_quit.query('quit != "yes"')['salary'].mean(), 1))
# Out:
# Средняя зарплата у уволившихся сотрудников: 23885.1
# Средняя зарплата у оставшихся сотрудников: 37702.2

# %% [markdown]
# Средняя зарплата у осташихся сотрудников почти в два раза выше, чем у уволившихся.

# %% [markdown]
# На графике выше явно видна зависимость: недовольство зарплатой ведет к увольнению.

# %% [markdown]
# <span style="color: blue; font-weight: bold">Комментарий ревьюера : </span> ✔️\
# <span style="color: green"> 👍</span>

# %% [markdown]
# #### Зависимость одного целевого признака от другого

# %% [markdown]
# Аналитики утверждают, что уровень удовлетворённости сотрудника работой в компании влияет на то, уволится ли сотрудник. Провим это утверждение: визуализируем и сравним распределения признака job_satisfaction_rate для ушедших и оставшихся сотрудников. Используем данные с обоими целевыми признаками тестовой выборки.

# %%
# объединим данные тестовой выборки и первого целевого признака
df_merge_test = test_features.merge(test_target_job_satisfaction_rate, on='id', how='left')

# hазмеры после первого объединения
print("Размеры после первого объединения:", df_merge_test.shape)  

# выведем первые строки таблицы для проверки
display(df_merge_test.head())
df_merge_test.info()
# Out:
# Размеры после первого объединения: (2000, 10)
#        id        dept   level workload  employment_years last_year_promo  \
# 0  100298          hr  junior      low                 2              no
# 1  100480   marketing  junior      low                 4              no
# 2  100503  purchasing  middle     high                 5              no
# 3  100610       sales  middle   medium                 5              no
# 4  100692       sales  middle     high                 6              no
#
#   last_year_violations  supervisor_evaluation  salary  job_satisfaction_rate
# 0                   no                      4   19200                   0.80
# 1                   no                      4   16800                   0.84
# 2                   no                      4   55200                   0.79
# 3                   no                      4   43200                   0.75
# 4                   no                      4   48000                   0.69
# ...

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера : </b></font> ✔️\
# <font color='green'> Верно, при объединении таблиц нужно привязаться к уникальному `"id"`.</font>

# %%
# объединим данные полученной таблицы и второго целевого признака
df_merge_test_full = df_merge_test.merge(test_target_quit, on='id', how='left')

# размеры после второго объединения
print("Размеры после второго объединения:", df_merge_test_full.shape)  

# выведем первые строки итоговой таблицы для проверки
display(df_merge_test_full.head())
df_merge_test_full.info()
# Out:
# Размеры после второго объединения: (2000, 11)
#        id        dept   level workload  employment_years last_year_promo  \
# 0  100298          hr  junior      low                 2              no
# 1  100480   marketing  junior      low                 4              no
# 2  100503  purchasing  middle     high                 5              no
# 3  100610       sales  middle   medium                 5              no
# 4  100692       sales  middle     high                 6              no
#
#   last_year_violations  supervisor_evaluation  salary  job_satisfaction_rate  \
# 0                   no                      4   19200                   0.80
# 1                   no                      4   16800                   0.84
# 2                   no                      4   55200                   0.79
# 3                   no                      4   43200                   0.75
# 4                   no                      4   48000                   0.69
#
#   quit
# 0   no
# ...

# %% [markdown]
# Построим график и посмотрим на распределение признаков.

# %%
fig, axes = plt.subplots(figsize=(8,6))
plt.title('Зависимость между увольнениями и удовлетворенностью от работы',  fontsize=14)
sns.histplot(stat='density', common_norm=False, data=df_merge_test_full, x='job_satisfaction_rate', hue='quit')
plt.xlabel('Удовлетворенность, от 0 до 1', fontsize=13)
plt.ylabel('Плотность распределения', fontsize=13)
plt.show()

# %% [markdown]
# Наблюдаем явное смещение: большинство уволившихся сотрудников оценили свою удовлетворенность работой ниже среднего.

# %% [markdown]
# <span style="color: blue; font-weight: bold">Комментарий ревьюера : </span> ✔️\
# <span style="color: green"> 👍</span>

# %%
# выделим тех, кто уволился, в отдельный датасет
gone = df_merge_test_full.drop('id', axis=1).query('quit == "yes"')
gone.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 564 entries, 10 to 1999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   dept                   564 non-null    object
#  1   level                  564 non-null    object
#  2   workload               564 non-null    object
#  3   employment_years       564 non-null    int64
#  4   last_year_promo        564 non-null    object
#  5   last_year_violations   564 non-null    object
#  6   supervisor_evaluation  564 non-null    int64
#  7   salary                 564 non-null    int64
#  8   job_satisfaction_rate  564 non-null    float64
#  9   quit                   564 non-null    object
# dtypes: float64(1), int64(3), object(6)
# memory usage: 48.5+ KB

# %%
# посмотрим на среднее значение удовлетворенности
gone['job_satisfaction_rate'].describe()
# Out:
# count    564.000000
# mean       0.387713
# std        0.185784
# min        0.040000
# 25%        0.240000
# 50%        0.370000
# 75%        0.492500
# max        0.970000
# Name: job_satisfaction_rate, dtype: float64

# %%
# выделим тех, кто остался, в отдельный датасет
remained = data=df_merge_test_full.drop('id', axis=1).query('quit == "no"')
remained.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1436 entries, 0 to 1998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   dept                   1436 non-null   object
#  1   level                  1436 non-null   object
#  2   workload               1436 non-null   object
#  3   employment_years       1436 non-null   int64
#  4   last_year_promo        1436 non-null   object
#  5   last_year_violations   1436 non-null   object
#  6   supervisor_evaluation  1436 non-null   int64
#  7   salary                 1436 non-null   int64
#  8   job_satisfaction_rate  1436 non-null   float64
#  9   quit                   1436 non-null   object
# dtypes: float64(1), int64(3), object(6)
# memory usage: 123.4+ KB

# %%
# посмотрим на среднее значение удовлетворенности у них
remained['job_satisfaction_rate'].describe()
# Out:
# count    1436.000000
# mean        0.612040
# std         0.199367
# min         0.030000
# 25%         0.500000
# 50%         0.660000
# 75%         0.760000
# max         1.000000
# Name: job_satisfaction_rate, dtype: float64

# %% [markdown]
# Среднее значение удовлетворенности у тех, кто остался работать — 0.61, у уволившихся — 0.38.

# %%
remained['job_satisfaction_rate'].median()
# Out:
# 0.66

# %%
gone['job_satisfaction_rate'].median()
# Out:
# 0.37

# %% [markdown]
# Медианные значения практически повторяют средние значения.
#
# Исследование показало, что есть прямая зависимость факта увольнения сотрудника от его удовлетворенности работой — поэтому на следующем шаге возьмем в работу новый входной признак, предсказанный лучшей моделью в первой задаче.

# %% [markdown]
# <span style="color: blue; font-weight: bold">Комментарий ревьюера : </span> ✔️\
# <span style="color: green"> 👍</span>

# %% [markdown]
# ### Шаг 4. Добавление нового входного признака

# %% [markdown]
# Добавим признак job_satisfaction_rate, предсказанный лучшей моделью первой задачи, к входным признакам второй задачи.

# %%
test_features_new = df_merge_test_full.copy()
test_features_new['job_satisfaction_rate_pred'] = grid.predict(X_test)
test_features_new = test_features_new.drop(['job_satisfaction_rate'], axis=1)
test_features_new.head()
# Out:
#        id        dept   level workload  employment_years last_year_promo  \
# 0  100298          hr  junior      low                 2              no
# 1  100480   marketing  junior      low                 4              no
# 2  100503  purchasing  middle     high                 5              no
# 3  100610       sales  middle   medium                 5              no
# 4  100692       sales  middle     high                 6              no
#
#   last_year_violations  supervisor_evaluation  salary quit  \
# 0                   no                      4   19200   no
# 1                   no                      4   16800   no
# 2                   no                      4   55200   no
# 3                   no                      4   43200   no
# 4                   no                      4   48000   no
#
#    job_satisfaction_rate_pred
# 0                    0.836522
# 1                    0.852000
# 2                    0.738000
# 3                    0.824643
# ...

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера : </b></font> ✔️\
# <font color='green'> Отлично, что добавляется предсказание предыдущей модели.</font>

# %%
test_features_new['job_satisfaction_rate_pred'].describe()
# Out:
# count    2000.000000
# mean        0.550357
# std         0.217139
# min         0.030000
# 25%         0.365000
# 50%         0.580923
# 75%         0.700000
# max         0.990000
# Name: job_satisfaction_rate_pred, dtype: float64

# %%
# на всякий случай проверим пропуски
test_features_new['job_satisfaction_rate_pred'].isna().sum()
# Out:
# 0

# %% [markdown]
# Добавим к тренировочной выборке данные целевого признака, предсказанного лучшей моделью в первой задаче.

# %%
train_quit_new = train_quit.drop('id', axis=1)
train_quit_new.duplicated().sum()
# Out:
# 1413

# %%
train_quit_new
# Out:
#             dept   level workload  employment_years last_year_promo  \
# 0          sales  middle     high                 2              no
# 1          sales  junior   medium                 2              no
# 2     purchasing  middle   medium                 5              no
# 3          sales  junior   medium                 2              no
# 4      marketing  junior   medium                 2              no
# ...          ...     ...      ...               ...             ...
# 3995       sales  junior   medium                 4              no
# 3996       sales  middle     high                 9              no
# 3997  purchasing  junior      low                 2              no
# 3998  purchasing  middle   medium                 2              no
# 3999       sales  junior   medium                 2              no
#
#      last_year_violations  supervisor_evaluation  salary quit
# 0                      no                      4   54000   no
# ...

# %%
X_train_quit_new = train_quit_new.drop('quit', axis=1)

y = grid.predict(X_train_quit_new) #предсказание уровня удовлетворенности для новой тестовой выборки

X_train_quit_new['job_satisfaction_rate_pred'] = pd.DataFrame(y) #добавление нового входного признака
X_train_quit_new
# Out:
#             dept   level workload  employment_years last_year_promo  \
# 0          sales  middle     high                 2              no
# 1          sales  junior   medium                 2              no
# 2     purchasing  middle   medium                 5              no
# 3          sales  junior   medium                 2              no
# 4      marketing  junior   medium                 2              no
# ...          ...     ...      ...               ...             ...
# 3995       sales  junior   medium                 4              no
# 3996       sales  middle     high                 9              no
# 3997  purchasing  junior      low                 2              no
# 3998  purchasing  middle   medium                 2              no
# 3999       sales  junior   medium                 2              no
#
#      last_year_violations  supervisor_evaluation  salary  \
# 0                      no                      4   54000
# ...

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ❌\
# <font color='red'> ~~К обучающим данным нужно, так же, добавить job_satisfaction_rate как предсказание первой модели.~~</font>

# %% [markdown]
# <div class="alert alert-info">
#
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
#
#
# А как это можно сделать, если в количество строк не совпадает? Я правильно понимаю, что к данным тренировочной выборки второй задачи `train_quit` ты предлагаешь добавить столбец с данными, предсказанными первой лучшей моделью? Но в этих данных 2000 строк, а в датасете с тренировочной выборкой — 4000.
#
# </div>

# %% [markdown]
# <span style="color: blue; font-weight: bold">Комментарий ревьюера 2: </span>  ❌\
# <span style="color: red"> ~~Для добавлнения job_satisfaction_rate к обучающимм данным, нужно предсказывать **обучающие** данные.~~ (.pedict(X_train)) </span>

# %% [markdown]
# <div class="alert alert-info">
#
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
#
#
# Спасибо, получилось.
#
# </div>

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера 3: </b></font> ✔️\
# <font color='green'> Отлично, что добавляется предсказание предыдущей модели.</font>

# %% [markdown]
# ### Шаг 5. Подготовка данных

# %% [markdown]
# Подготовим признаки так же, как и в первой задаче: выполним подготовку в пайплайне, дополнив пайплайн предобработки. При кодировании будем учитывать особенности признаков и моделей и используем как минимум два кодировщика.

# %% [markdown]
# #### Сортировка столбцов в датасетах

# %%
test_features_new = test_features_new.sort_values(by='id').reset_index(drop=True)
test_features_new.head()
# Out:
#        id        dept   level workload  employment_years last_year_promo  \
# 0  100298          hr  junior      low                 2              no
# 1  100480   marketing  junior      low                 4              no
# 2  100503  purchasing  middle     high                 5              no
# 3  100610       sales  middle   medium                 5              no
# 4  100692       sales  middle     high                 6              no
#
#   last_year_violations  supervisor_evaluation  salary quit  \
# 0                   no                      4   19200   no
# 1                   no                      4   16800   no
# 2                   no                      4   55200   no
# 3                   no                      4   43200   no
# 4                   no                      4   48000   no
#
#    job_satisfaction_rate_pred
# 0                    0.836522
# 1                    0.852000
# 2                    0.738000
# 3                    0.824643
# ...

# %%
test_target_quit = test_target_quit.sort_values(by='id').reset_index(drop=True)
test_target_quit.head()
# Out:
#        id quit
# 0  100298   no
# 1  100480   no
# 2  100503   no
# 3  100610   no
# 4  100692   no

# %%
# создание тренировочной выборки входных признаков и целевого признака
X_train_quit = X_train_quit_new
y_train_quit = train_quit_new['quit'] 
X_test_quit = test_features_new.drop(['quit'], axis=1) 
y_test_quit = test_target_quit['quit']  

RANDOM_STATE = 100
TEST_SIZE = 0.25
stratify = y_test_quit

# %%
# создание списков переменных датасета X_train_quit
num_col = ['employment_years', 
           'supervisor_evaluation', 
           'salary',
           'job_satisfaction_rate_pred']

ord_col = ['level', 
           'workload']           

ohe_col = [
           'last_year_promo',
           'last_year_violations']

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ❌\
# <font color='red'>~~Нужно добавить job_satisfaction_rate в num_col.~~</font>

# %%
# пайплайн для кодирования категориальных признаков
ohe_pipe = Pipeline(
    [
        ('simpleImputer_ohe', 
         SimpleImputer(missing_values=np.nan, 
                       strategy='most_frequent')), 
        ('ohe', 
         OneHotEncoder(drop='first', 
                       handle_unknown='ignore', 
                       ))
    ]
)

# %%
# пайплайн для кодирования категориальных ранговых признаков
ord_pipe = Pipeline(
    [('simpleImputer_before_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent')),
     ('ord',  OrdinalEncoder(
                categories=[                    
                    ['low', 'medium', 'high'],
                    ['junior', 'middle', 'senior'],
                    
                ], 
                handle_unknown='use_encoded_value', unknown_value=np.nan
            )
        ),
     ('simpleImputer_after_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent'))
    ]
)

# %%
# пайплайн для подготовки данных
data_preprocessor = ColumnTransformer(
    [
        ('ohe', ohe_pipe, ohe_col),
        ('ord', ord_pipe, ord_col),
        ('num', StandardScaler(), num_col)
    ], 

)

# %% [markdown]
# <span style="color: blue; font-weight: bold">Комментарий ревьюера : </span> ✔️\
# <span style="color: green"> 👍</span>

# %%
# итоговый пайплайн: подготовка данных и модель
pipe_final_1 = Pipeline([
    ('preprocessor', data_preprocessor),
    ('models', DecisionTreeClassifier(random_state=RANDOM_STATE))
])

# %% [markdown]
# <span style="color: blue; font-weight: bold">Комментарий ревьюера : </span> ⚠️\
# <span style="color: darkorange">Regressor ❓</span>

# %% [markdown]
# <div class="alert alert-info">
#
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
#
#
# Уточни, пожалуйста, что означает этот комментарий.
#
# </div>

# %% [markdown]
# <span style="color: blue; font-weight: bold">Комментарий ревьюера 2: </span> ⚠️\
# <span style="color: darkorange"> Здесь задача Классификации, зачем в Базовый Pipeline вставлять Модель Регрессии?</span>

# %% [markdown]
# <div class="alert alert-info">
#
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
#
#
# Сразу не разобралась, исправила.
#
# </div>

# %% [markdown]
# <span style="color: blue; font-weight: bold">Комментарий ревьюера 3: </span> ✔️\
# <span style="color: green">👍</span>

# %% [markdown]
# ### Шаг 6. Обучение моделей

# %%
# параметры для передачи GridSearchCV для поиска оптимальной модели 
# с разными Scaler и Encoder и перебором гиперпараметров

param_distributions_1 = [
    {
        'models': [KNeighborsClassifier()],
        'models__n_neighbors': range(1, 15),
        'preprocessor__num': [StandardScaler(), MinMaxScaler()]   
    },
    {
        'models': [DecisionTreeClassifier(random_state=RANDOM_STATE)],
        'models__max_depth': range(2, 11),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    },
    {
        'models': [SVC(random_state=RANDOM_STATE, probability=True)],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  

    },
    {
        'models': [LogisticRegression(random_state=RANDOM_STATE)],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    }
]

# %% [markdown]
# <span style="color: blue; font-weight: bold">Комментарий ревьюера : </span> ✔️\
# <span style="color: green"> 👍</span>

# %%
# поиск оптимальной модели с перебором гиперпараметров
grid_1 = GridSearchCV(
    pipe_final_1, 
    param_grid=param_distributions_1, 
    cv=5, 
    scoring='roc_auc', 
    n_jobs=-1, 
)

# %%
grid_1.fit(X_train_quit, y_train_quit);

# %%
print('Метрика ROC-AUC для лучшей модели:\n', round(grid_1.best_score_, 2)) 
print('\nЛучшая модель и её параметры:\n\n', grid_1.best_params_)
# Out:
# Метрика ROC-AUC для лучшей модели:
#  0.92
#
# Лучшая модель и её параметры:
#
#  {'models': KNeighborsClassifier(), 'models__n_neighbors': 14, 'preprocessor__num': StandardScaler()}

# %% [markdown]
# <span style="color: blue; font-weight: bold">Комментарий ревьюера : </span> ✔️\
# <span style="color: green"> 👍</span>

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ❌\
# <font color='red'> ~~Нужно вывести результаты оценки Топ-10 лучших моделей, для анализа.~~</font>

# %% [markdown]
# <div class="alert alert-info">
#
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
#
#
# Сделано.
#
# </div>

# %% [markdown]
# <span style="color: blue; font-weight: bold">Комментарий ревьюера 2: </span> ✔️\
# <span style="color: green"> 👍</span>

# %%
pd.set_option('display.max_colwidth', None)
pd.DataFrame(grid_1.cv_results_)[
    ['std_test_score', 'rank_test_score', 'param_models', 'mean_test_score','params']
].sort_values('rank_test_score').head(10)
# Out:
#     std_test_score  rank_test_score            param_models  mean_test_score  \
# 26        0.003017                1  KNeighborsClassifier()         0.923140
# 24        0.003449                2  KNeighborsClassifier()         0.922894
# 19        0.006880                3  KNeighborsClassifier()         0.922642
# 23        0.006997                4  KNeighborsClassifier()         0.922435
# 27        0.005077                5  KNeighborsClassifier()         0.922395
# 25        0.006334                6  KNeighborsClassifier()         0.922368
# 17        0.005916                7  KNeighborsClassifier()         0.922211
# 18        0.005960                8  KNeighborsClassifier()         0.922036
# 21        0.006718                9  KNeighborsClassifier()         0.921964
# 20        0.005431               10  KNeighborsClassifier()         0.921685
#
#                                                                                                   params
# ...

# %%
#y_pred = grid_1.predict(X_test_quit)
y_true = grid_1.predict_proba(X_test_quit)
print(f'Метрика ROC-AUC на тестовой выборке: {round(roc_auc_score(y_test_quit, y_true[:,1]), 3)}')
# Out:
# Метрика ROC-AUC на тестовой выборке: 0.912

# %% [markdown]
# <span style="color: blue; font-weight: bold">Комментарий ревьюера : </span>  ❌\
# <span style="color: red">~~В метрику подаётся (таргет, вероятности класса)~~  </span>

# %% [markdown]
# <div class="alert alert-info">
#
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
#
#
# Уточни, пожалуйста, что означает этот комментарий. Сейчас код поломан — выше я задала вопросы на этот счет.
#
# </div>

# %% [markdown]
# <span style="color: blue; font-weight: bold">Комментарий ревьюера : </span>  ❌\
# <span style="color: red"> ~~Для расчёта roc_auc_score, первым аргументом подаётся реальные значения признака (это данные из test_target_quit.csv), вторым аргументом подаются вероятности классов, предсказанные моделью.~~</span>

# %% [markdown]
# <div class="alert alert-info">
#
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
#
# Поняла, спасибо! Поправила. Но метрика выходит очень низкой. Подскажи, пожалуйста, в чем ошибка — я подозреваю, что на этапе добавления нового признака к обучающим данным.
#
#
# </div>

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера 3: </b></font> ❌\
# <font color='red'> ~~Индексы в df_test и df_target не совпадают и сейчас таргеты не соотвествуют своим фичам. Нужно согласовать данные по общему униакальному признаку, в данном случае подойдёт 'id'.\
# В первой задаче у тебя есть сортировка по id, а здесь - нет.~~</font>

# %% [markdown]
# <div class="alert alert-info">
#
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
#
#
# Спасибо большое! Сделала.
#
# </div>

# %% [markdown]
# <span style="color: blue; font-weight: bold">Комментарий ревьюера 4: </span> ✔️\
# <span style="color: green"> Отлично! ROC-AUC ≥0.91</span>

# %%
#поиск важных признаков
X_encoded_1 = grid_1.best_estimator_['preprocessor'].fit_transform(X_train_quit)

model_1 = grid_1.best_estimator_['models'].fit(X_encoded_1, y_train_quit)
explainer_1 = shap.PermutationExplainer(model_1, X_encoded_1)


labels_1 = grid_1.best_estimator_[:-1].get_feature_names_out()

plt.title('Агрегированный вклад признаков в прогнозы модели', fontsize=18)
plt.ylabel('Исследуемые признаки', fontsize=14)
shap.summary_plot(X_encoded_1, plot_type='bar', feature_names=labels_1)

# %% [markdown]
# ### Промежуточный вывод

# %% [markdown]
# Критерий успеха — метрика ROC-AUC ≥0.91 — достигнут. На основе метрики ROC-AUC была отобрана лучшая модель KNeighborsClassifier. Получена метрика ROC-AUC на тестовой выборке со значением 1.
#
# Наиболее значимыми признаками оказались удовлетворенность работой, количество отработанных в компании лет, оценка от руководителя и зарплата.

# %% [markdown]
# <span style="color: blue; font-weight: bold">Комментарий ревьюера : </span> ✔️\
# <span style="color: green"> 👍</span>

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# Удовлетворённость работой напрямую влияет на отток сотрудников. А предсказание оттока — одна из важнейших задач HR-аналитиков. Внезапные увольнения несут в себе риски для компании, особенно если уходит важный сотрудник.

# %% [markdown]
# Итак, перед нами были поставлены две задачи:
# - построить модель, которая сможет предсказать уровень удовлетворённости сотрудника на основе данных заказчика;
# - построить модель, которая сможет на основе данных заказчика предсказать то, что сотрудник уволится из компании.

# %% [markdown]
# Вот какие шаги были сделаны для решения задач:
#
# - загрузка и изучение данных;
# - предобработка данных;
# - исследовательский анализ данных (визуализация);
# - корреляционный анализ данных;
# - построение пайплайнов;
# - обучение моделей (для первой задачи — две модели, для второй — три), выявление самых лучших;
# - формирование портрета довольного и уволившегося сотрудников;
# - выявление зависимости меджу целевыми признаками «удовлетворенность работой» и «факт увольнения».

# %% [markdown]
# В результате исследования выявлена прямая зависимость перкспективы увольнения от удовлетворенности сотрудника его работой в компании, а также обучены две модели, которые с высокой точностью предсказывают оба этих показателя.

# %% [markdown]
# Исследование данных, которые указаны при анкетировании, подсветило некоторые моменты и закономерности, на которые руководству точно стоит обратить внимание.
#
#
# Довольно много сотрудников работает в компании меньше четырех лет, много новичков — с одной стороны, это процесс естественный и приток свежей крови нужен — особенно, если речь идет об отделе продаж, который, как мы выяснили, самый многолюдный. Люди часто приходят в продажи от безысходности, безденежья или когда не знают, кем хотят стать, потому что считают, что в продажах не нужен опыт и особое образование — а, меж тем, эта деятельность не самая простая. В результате мы видим, что первые кандидаты на увольнение это люди, которые отработали год или два — и треть из них в отделе продаж. Половина из этих людей не была перегружена работой — они оценили свою загрузку как низкую. Ну и, разумеется, зарплатные ожидания у уволившихся сотрудников явно не совпали с планами руководства. А еще, работа большинства из них была оценена руководством на 3.
#
# В связи с тем, какой у нас нарисовался «портрет недовольного и ушедшего сотрудника», можно выдать бизнесу следующие рекомендации:
# - **добавить транспарентности в систему оценок**: что конкретно оценивается? Понимают ли сотрудники, как те или иные действия влияют на будущую оценку? Что вообще означают эти цифры и почему именно 5 — когда сотрудники оценивают свою удовлетворенность практически по десятибалльной шкале (от 0 до 1)? Может быть, саму систему оценивания нужно изменить: например, если в ней слишком много субъективности — превратить ее в механизм регулярного ревью с привлечением не одного руководителя, а нескольких;
# - **вероятно, стоит добавить грейдов внутри грейдов**: может быть, люди «засиживаются» на базовом уровне, при этом показывая результат выше среднего, но не встречают инициативы со стороны руководства.
# - **обратить внимание на «кризис первого года»**: может быть, хромает система онбординга? Или людям нужен «бадди», который будет помогать в адаптации? Или может люди не понимают перспектив по итогу первого года в компании?
# - **пересмотреть процессы в отделе продаж**: возможно, они уже неэффективны. Может быть, следует получать больше обратной связи от сотрудников, внедрить какие-то внерабочие активности, дать понять сотрудникам, что они важны;
# - **пересмотреть процессы в разрезе распределения задач**: многие люди уйдут, если будут понимать, что у них нет нагрузки, маленькая зарплата — а ресурс еще есть;
# - добавить больше открытости к обсуждению зарплаты или сделать более прозрачной систему ее начисления;
# - **обратить внимание на нарушения трудового договора**: нужно понять, какие именно пункты нарушаются чаще всего и почему — чего не хватает сотрудникам, например — а также как это предотвратить.

# %% [markdown]
# Львиная доля советов может быть реализована, если собирать с сотрудников больше обратной связи — и желательно делать это системно, но ненавязчиво: нужно показать открытость руководства к диалогу и стремление исправить недостатки процессов, а также уже достигнутые результаты — чтобы люди видели, что система работает.

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ✔️\
# <font color='green'> Очень приятно видеть вывод в конце проекта!\
# Приведены ответы на главные вопросы проекта.</font>

# %% [markdown]
# <font color='blue'><b>Итоговый комментарий ревьюера</b></font>\
# <font color='green'>Ксения, хороший проект получился!
# Большое спасибо за проделанную работу. Видно, что приложено много усилий.
# Выводы и рассуждения получились содержательными, их было интересно читать.
# </font>
#
# <font color='steelblue'>Над проектом ещё стоит поработать - есть рекомендации по дополнению некоторых твоих шагов проекта. Такие рекомендации я отметил жёлтыми комментариями. Будет здорово, если ты учтёшь их - так проект станет структурно и содержательно более совершенным.
#
# Также в работе есть критические замечания. К этим замечаниям я оставил пояснительные комментарии красного цвета, в которых перечислил возможные варианты дальнейших действий. Уверен, ты быстро с этим управишься:)
#
# Если о том, что нужно сделать в рамках комментариев, будут возникать вопросы - оставь их, пожалуйста, в комментариях, и я отвечу на них во время следующего ревью.
#
# Также буду рад ответить на любые твои вопросы по проекту или на какие-либо другие, если они у тебя имеются - оставь их в комментариях, и я постараюсь ответить:)</font>
#
# <font color='blue'><b>Жду твой проект на повторном ревью. До встречи :) </b></font>

# %% [markdown]
# <font color='blue'><b>Итоговый комментарий ревьюера 2</b></font>\
# <font color='green'>Ксения, большое спасибо за доработку.
# </font>
#
# <font color='steelblue'>Над проектом ещё стоит поработать - есть рекомендации по дополнению некоторых твоих шагов проекта. Такие рекомендации я отметил жёлтыми комментариями. Будет здорово, если ты учтёшь их - так проект станет структурно и содержательно более совершенным.
#
# Также в работе есть критические замечания. К этим замечаниям я оставил пояснительные комментарии красного цвета, в которых перечислил возможные варианты дальнейших действий. Уверен, ты быстро с этим управишься:)
#
# Если о том, что нужно сделать в рамках комментариев, будут возникать вопросы - оставь их, пожалуйста, в комментариях, и я отвечу на них во время следующего ревью.
#
# Также буду рад ответить на любые твои вопросы по проекту или на какие-либо другие, если они у тебя имеются - оставь их в комментариях, и я постараюсь ответить:)</font>
#
# <font color='blue'><b>Жду твой проект на повторном ревью. До встречи :) </b></font>

# %% [markdown]
# <font color='blue'><b>Итоговый комментарий ревьюера 3</b></font>\
# <font color='green'>Ксения, большое спасибо за доработку.
# </font>
#
# <font color='blue'>Что нужно исправить:</font>
# <ul><font color='red'>Оставь значения `' '` для Энкодеров.</font></ul>
# <ul><font color='red'>Поправь формирование тестовых предиктеров и таргетов во второй задаче.</font></ul>
#
# <font color='blue'>Что можно сделать лучше:</font>
# <font color='darkorange'>В работе я оставил несколько советов. Буду рад, если ты учтешь их.</font></ul>
#
# <font color='blue'><b>Жду новую версию проекта :)</b></font>

# %% [markdown]
# <font color='blue'><b>Итоговый комментарий ревьюера 4</b></font>\
# <font color='green'> Ксения, проект принят! \
# Все этапы пройдены. Все рекомендации учтены.\
# Надеюсь, тебе понравился процесс выполнения и результат.</font> \
# <font color='blue'><b>Спасибо, удачи в освоении профессии!</b></font>
